# %%
import requests as r

# %%
url = "https://api.coinbase.com/v2/exchange-rates"

# %%
params = { "currency": "BTC" }
resp = r.get(url, params=params)
resp.json()['data']['rates']['BRL']
# Out:
# '224086.174104'

# %%
resp.json()
# Out:
# {'data': {'currency': 'BTC',
#   'rates': {'00': '554843.056397816859104505',
#    '1INCH': '94786.7298578199052133',
#    'AAVE': '396.1180431768667063',
#    'ABT': '221052.476443585408775427',
#    'ACH': '2053590.555069243373552722',
#    'ACS': '14206863.247465101473656604',
#    'ADA': '73019.3501277838627236',
#    'AED': '168012.021684218751198503',
#    'AERGO': '294475.764402961057721438',
#    'AFN': '3232341.468730827251959169',
#    'AGLD': '31286.28778552865463099',
#    'AIOZ': '258968.638550806681064126',
#    'ALCX': '1354.25725281231541264',
#    'ALEPH': '338865.259259259258920394',
#    'ALGO': '190839.6946564885496183',
#    'ALICE': '30847.478084962911234261',
#    'ALL': '4338862.164408705',
#    'AMD': '18521983.80372816',
#    'AMP': '12281022.818791946308878345',
#    'ANG': '82177.481697541554214239',
#    'ANKR': '1503759.3984962406015038',
#    'ANT': '7423.353871279043872',
#    'AOA': '37939338.744055927697746197',
# ...
